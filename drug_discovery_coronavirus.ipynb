# %% [markdown]
# <a href="https://colab.research.google.com/github/anshi-kaaaa/Drug-Discovery/blob/main/drug_discovery_coronavirus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Inspired by https://github.com/dataprofessor/code/blob/master/python/CDD_ML_Part_1_Bioactivity_Data_Concised.ipynb
! pip install chembl_webresource_client
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client
# Out:
# ...
#      |████████████████████████████████| 61kB 6.6MB/s
# ...

# %% [markdown]
# Chembl database majorly includes small molecule data

# %%
# Target search for SARS coronavirus
target = new_client.target
target_query = target.search('SARS coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references  ...   tax_id
# 0                                                  []  ...   227859
# 1   [{'xref_id': 'P0C6U8', 'xref_name': None, 'xre...  ...   227859
# 2                                                  []  ...    11119
# 3                                                  []  ...    12663
# 4                                                  []  ...   694009
# 5                                                  []  ...     9606
# 6                                                  []  ...    11137
# 7                                                  []  ...  2697049
# 8   [{'xref_id': 'P0C6X7', 'xref_name': None, 'xre...  ...   227859
# 9                                                  []  ...  1335626
# 10                                                 []  ...  2697049
#
# [11 rows x 9 columns]

# %%
selected_target = targets.target_chembl_id[1]
selected_target
# Out:
# 'CHEMBL3927'

# %% [markdown]
# Target types are majorly divided as molecular and non-molecular.
#
# > Molecular target types inludes nucleic acids and protein.
#
#
#
# Protein can be further divided as single protein, protein complex and protein family.
#
#
# > Non- molecular target type includes cell-line, tissue, subcellular fraction and organism.
#
# Here, we are choosing SARS Coronavirus 3C-like proteinase, as it is very important in the processing of coronaviral polyproteins and could be an effective drug target.

# %%
activity = new_client.activity
resource = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %% [markdown]
# We will retrieve the bioactivity data that are reported as IC50 value.

# %% [markdown]
# IC50 represents the concentration at which a substance exerts half of its maximal inhibitory effect.

# %%
dataframe = pd.DataFrame.from_dict(resource)

# %%
dataframe_filtered = dataframe[dataframe.standard_value.notna()]
dataframe_filtered
# Out:
#     activity_comment  activity_id  ... upper_value  value
# 0               None      1480935  ...        None    7.2
# 1               None      1480936  ...        None    9.4
# 2               None      1481061  ...        None   13.5
# 3               None      1481065  ...        None  13.11
# 4               None      1481066  ...        None    2.0
# ..               ...          ...  ...         ...    ...
# 128             None     12041507  ...        None   10.6
# 129             None     12041508  ...        None   10.1
# 130             None     12041509  ...        None   11.5
# 131             None     12041510  ...        None   10.7
# 132             None     12041511  ...        None   78.9
#
# [133 rows x 45 columns]

# %%
bioactivity_class = []
for i in dataframe_filtered.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
   bioactivity_class.append("intermediate")

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
selected_columns = dataframe_filtered[selection]
selected_columns
# Out:
#     molecule_chembl_id  ... standard_value
# 0         CHEMBL187579  ...         7200.0
# 1         CHEMBL188487  ...         9400.0
# 2         CHEMBL185698  ...        13500.0
# 3         CHEMBL426082  ...        13110.0
# 4         CHEMBL187717  ...         2000.0
# ..                 ...  ...            ...
# 128      CHEMBL2146517  ...        10600.0
# 129       CHEMBL187460  ...        10100.0
# 130       CHEMBL363535  ...        11500.0
# 131       CHEMBL227075  ...        10700.0
# 132        CHEMBL45830  ...        78900.0
#
# [133 rows x 3 columns]

# %%
bioactivity_class = pd.Series(bioactivity_class, name='bioactivity_class')
bioactivity_data = pd.concat([selected_columns, bioactivity_class], axis=1)
bioactivity_data
# Out:
#     molecule_chembl_id  ... bioactivity_class
# 0         CHEMBL187579  ...      intermediate
# 1         CHEMBL188487  ...      intermediate
# 2         CHEMBL185698  ...          inactive
# 3         CHEMBL426082  ...          inactive
# 4         CHEMBL187717  ...      intermediate
# ..                 ...  ...               ...
# 128      CHEMBL2146517  ...          inactive
# 129       CHEMBL187460  ...          inactive
# 130       CHEMBL363535  ...          inactive
# 131       CHEMBL227075  ...          inactive
# 132        CHEMBL45830  ...          inactive
#
# [133 rows x 4 columns]

# %%
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
! conda install -c rdkit rdkit -y
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2021-05-09 07:21:30--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M   167MB/s    in 0.5s
#
# 2021-05-09 07:21:31 (167 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
# ...

# %%
import numpy as np
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski

# %%
# Inspired by: https://codeocean.com/explore/capsules?query=tag:data-curation

def lipinski(smiles, verbose=False):

    moldata= []
    for elem in smiles:
        mol=Chem.MolFromSmiles(elem) 
        moldata.append(mol)
       
    baseData= np.arange(1,1)

    for i,mol in enumerate(moldata):        
        desc_MolWt = Descriptors.MolWt(mol)
        desc_MolLogP = Descriptors.MolLogP(mol)
        desc_NumHDonors = Lipinski.NumHDonors(mol)
        desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)
           
        row = np.array([desc_MolWt,
                        desc_MolLogP,
                        desc_NumHDonors,
                        desc_NumHAcceptors])       
        if(i==0):
            baseData=row
        else:
            baseData=np.vstack([baseData, row])
    
    columnNames=["MW","LogP","NumHDonors","NumHAcceptors"]   
    descriptors = pd.DataFrame(data=baseData,columns=columnNames)
    
    return descriptors

# %%
df_lipinski = lipinski(dataframe.canonical_smiles)

# %%
df_lipinski
# Out:
#           MW     LogP  NumHDonors  NumHAcceptors
# 0    281.271  1.89262         0.0            5.0
# 1    415.589  3.81320         0.0            2.0
# 2    421.190  2.66050         0.0            4.0
# 3    293.347  3.63080         0.0            3.0
# 4    338.344  3.53900         0.0            5.0
# ..       ...      ...         ...            ...
# 128  338.359  3.40102         0.0            5.0
# 129  296.366  3.44330         0.0            3.0
# 130  276.291  4.09564         0.0            3.0
# 131  278.307  3.29102         0.0            3.0
# 132  282.383  4.10530         0.0            2.0
#
# [133 rows x 4 columns]

# %%
combined = pd.concat([bioactivity_data,df_lipinski], axis=1)

# %%
combined
# Out:
#     molecule_chembl_id  ... NumHAcceptors
# 0         CHEMBL187579  ...           5.0
# 1         CHEMBL188487  ...           2.0
# 2         CHEMBL185698  ...           4.0
# 3         CHEMBL426082  ...           3.0
# 4         CHEMBL187717  ...           5.0
# ..                 ...  ...           ...
# 128      CHEMBL2146517  ...           5.0
# 129       CHEMBL187460  ...           3.0
# 130       CHEMBL363535  ...           3.0
# 131       CHEMBL227075  ...           3.0
# 132        CHEMBL45830  ...           2.0
#
# [133 rows x 8 columns]

# %% [markdown]
# Here, we will be removing the intermediate class from our data set.

# %%
intermediate_removed = bioactivity_data[bioactivity_data.bioactivity_class != 'intermediate']
intermediate_removed
# Out:
#     molecule_chembl_id  ... bioactivity_class
# 2         CHEMBL185698  ...          inactive
# 3         CHEMBL426082  ...          inactive
# 5         CHEMBL365134  ...            active
# 7         CHEMBL190743  ...            active
# 8         CHEMBL365469  ...          inactive
# ..                 ...  ...               ...
# 128      CHEMBL2146517  ...          inactive
# 129       CHEMBL187460  ...          inactive
# 130       CHEMBL363535  ...          inactive
# 131       CHEMBL227075  ...          inactive
# 132        CHEMBL45830  ...          inactive
#
# [119 rows x 4 columns]

# %%
import seaborn as sns
sns.set(style='ticks')
import matplotlib.pyplot as plt

# %% [markdown]
# Frequency plot of the two bioactivity classes

# %%
plt.figure(figsize=(5.5, 5.5))

sns.countplot(x='bioactivity_class', data=intermediate_removed, edgecolor='black')

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('Frequency', fontsize=14, fontweight='bold')

plt.savefig('plot_bioactivity_class.pdf')

# %%
active_compound = bioactivity_data[bioactivity_data.bioactivity_class == 'active']
active_compound
# Out:
#     molecule_chembl_id  ... bioactivity_class
# 5         CHEMBL365134  ...            active
# 7         CHEMBL190743  ...            active
# 15        CHEMBL358279  ...            active
# 78        CHEMBL212454  ...            active
# 98        CHEMBL212218  ...            active
# 99        CHEMBL222840  ...            active
# 100       CHEMBL222769  ...            active
# 101       CHEMBL222735  ...            active
# 102       CHEMBL222628  ...            active
# 103       CHEMBL222893  ...            active
# 104       CHEMBL225515  ...            active
# 105       CHEMBL222234  ...            active
# 106       CHEMBL426898  ...            active
# 117       CHEMBL187460  ...            active
# 123       CHEMBL363535  ...            active
#
# [15 rows x 4 columns]
